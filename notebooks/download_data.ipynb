# %%
# %%shell
# sudo apt-get install parallel > /dev/null
# cd /content/drive/MyDrive/Documents/project/deep-learning/depth-estimation/data
# bash /content/drive/MyDrive/Documents/project/deep-learning/depth-estimation/data/parallel-data-download-script.sh
# Out:
# Starting parallel downloads and extractions...
# All downloads and extractions completed! Check "kitti_download_log.txt" for details.
